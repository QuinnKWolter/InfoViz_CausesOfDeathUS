# %%
import numpy as np, pandas as pd
pd.set_option('float_format', '{:.0f}'.format)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
mpl.style.use('ggplot')

import seaborn as sns

# %%
google_df = pd.read_csv('final_Google_by_year.csv', index_col=0)
google_df.head(10)
# Out:
#    Year  Accident  Alzheimers  CLRD  Stroke  Diabetes  Cancer  Suicide  Flu  \
# 0  2004        30           4     2       6        18      50       14   18
# 1  2005        30           4     2       6        17      50       13   27
# 2  2006        30           3     2       6        17      46       10   24
# 3  2007        33           3     2       5        17      45       10   17
# 4  2008        34           4     2       5        16      46       11   18
# 5  2009        40           4     2       5        16      46       11  100
# 6  2010        42           3     2       5        15      44       12   17
# 7  2011        43           4     3       6        14      44       11   18
# 8  2012        46           3     3       6        14      44       13   20
# 9  2013        50           3     3       6        14      44       12   29
#
#    Heart  Kidney
# 0      9       2
# 1      8       2
# 2      7       2
# 3      7       2
# 4      7       2
# 5      7       2
# 6      7       2
# 7      7       2
# 8      8       2
# 9      7       2

# %%
nchs_df = pd.read_csv('final_NCHS_by_year.csv', index_col=0)
nchs_df.head(10)
# Out:
#    Year  Alzheimers  CLRD  Cancer  Diabetes  Heart  Flu  Kidney  Stroke  \
# 0  2004          10    19      84        11    100    9       6      23
# 1  2005          11    20      84        11     98   10       7      22
# 2  2006          11    18      82        11     93    8       7      20
# 3  2007          11    19      81        10     88    8       7      20
# 4  2008          12    20      80        10     87    8       7      19
# 5  2009          11    19      78        10     82    7       7      18
# 6  2010          11    19      78         9     81    7       7      18
# 7  2011          11    19      76        10     78    7       6      17
# 8  2012          11    19      75        10     77    6       6      17
# 9  2013          11    19      74        10     77    7       6      16
#
#    Suicide  Accident
# 0        5        17
# 1        5        18
# 2        5        18
# 3        5        18
# 4        5        18
# 5        5        17
# 6        6        17
# 7        6        18
# 8        6        18
# 9        6        18

# %%
years = list(range(2004, 2018))
columns = ['Heart', 'Cancer', 'CLRD', 'Accident', 'Stroke', 'Alzheimers', 'Diabetes', 'Flu', 'Kidney', 'Suicide']
google_df = google_df.reindex(columns=columns)
google_df['Year'] = years
nchs_df = nchs_df.reindex(columns=columns)
nchs_df['Year'] = years
colors = ['firebrick', 'lightsalmon', 'khaki', 'forestgreen', 'turquoise', 'dodgerblue', 'indigo', 'violet', 'saddlebrown', 'black']

fig, (ax, ax2) = plt.subplots(ncols=2, sharey=True)
google_df.plot(x='Year', kind='bar', stacked=True, color=colors, ax = ax, figsize=(15,7), legend=False)
nchs_df.plot(x='Year', kind='bar', stacked=True, color=colors, ax = ax2, figsize=(15,7))
ax2.legend(bbox_to_anchor=(-0.1,1.2), loc='upper center', ncol=len(columns))
ax.get_yaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)
ax.set_title('What Americans Search For\n(Share of Google Search Interest)')
ax2.set_title('What Americans Die Of\n(Share of Leading Causes of Death)')
ax.set(xlabel=None)
ax2.set(xlabel=None)
plt.rc('xtick', labelsize=20) 

plt.show()
